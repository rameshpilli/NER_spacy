# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/apjanco/NER_spacy/blob/master/NER_spaCy.ipynb)

# %%
try:
    import spacy
except ImportError:
    # !pip install spacy
    import spacy

# %%
try:
    nlp = spacy.load('es_core_news_md')
except IOError:
    # !python -m spacy download en_core_web_sm
    nlp = spacy.load('es_core_news_md')
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz (37.4MB)
#     100% |████████████████████████████████| 37.4MB 79.1MB/s
# Installing collected packages: en-core-web-sm
# done
# Successfully installed en-core-web-sm-2.0.0
#
#     Linking successful
#     /usr/local/lib/python2.7/dist-packages/en_core_web_sm -->
#     /usr/local/lib/python2.7/dist-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from google.colab import files
uploaded = files.upload()
text = uploaded.values()[0] #.encode("utf-8")
doc = nlp(unicode(text, "utf-8"))
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
#      <input type="file" id="files-59ec42f6-2b30-41d8-beca-fcc3f2204710" name="files[]" multiple disabled />
#      <output id="result-59ec42f6-2b30-41d8-beca-fcc3f2204710">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nick.txt to nick (18).txt
# (u'Adri\xe1n/Adriano m', 9, 25, u'ORG')
# (u'Adriana f.\n', 30, 41, u'ORG')
# (u'Ale', 41, 44, u'PERSON')
# (u'Alejandra', 49, 58, u'PERSON')
# (u'Alejandro', 70, 79, u'GPE')
# (u'Argentina', 81, 90, u'GPE')
# (u'\n', 91, 92, u'GPE')
# (u'Alejandra', 102, 111, u'PERSON')
# (u'\nAlejo', 113, 119, u'ORG')
# (u'Ali', 157, 160, u'PERSON')
# (u'Alicia', 165, 171, u'PERSON')
# (u'\nAlmu', 173, 178, u'ORG')
# (u'Almudena', 183, 191, u'ORG')
# (u'\n', 193, 194, u'GPE')
# (u'Bel\xe9n', 209, 214, u'PERSON')
# (u'Ana Isabel', 218, 228, u'WORK_OF_ART')
# (u'\n', 254, 255, u'GPE')
# (u'\xc1ngela', 292, 298, u'PERSON')
# (u'\n', 300, 301, u'GPE')
# (u'Beatriz', 349, 356, u'GPE')
# (u'\n', 358, 359, u'GPE')
# (u'Bernab\xe9 m\n', 369, 379, u'ORG')
# (u'Berni for Bernardo', 379, 397, u'ORG')
# (u'\n', 399, 400, u'GPE')
# (u'Berta', 400, 405, u'GPE')
# (u'Alberta', 410, 417, u'GPE')
# (u'Humberta', 419, 427, u'GPE')
# (u'Norberta', 429, 437, u'GPE')
# (u'Roberta', 439, 446, u'GPE')
# (u'Rigoberta', 450, 459, u'GPE')
# (u'\n', 461, 462, u'GPE')
# (u'Norberto', 492, 500, u'PERSON')
# (u'Roberto', 502, 509, u'PERSON')
# (u'Rigoberto', 513, 522, u'PERSON')
# (u'\n', 524, 525, u'GPE')
# (u'Alberto', 535, 542, u'PERSON')
# (u'Norberto', 554, 562, u'PERSON')
# (u'Roberto', 564, 571, u'PERSON')
# (u'Rigoberto', 575, 584, u'PERSON')
# (u'\n', 586, 587, u'GPE')
# (u'Beatriz', 596, 603, u'GPE')
# (u'\n', 605, 606, u'GPE')
# (u'Alberto', 615, 622, u'PERSON')
# (u'Norberto', 634, 642, u'PERSON')
# (u'Roberto', 644, 651, u'PERSON')
# (u'Rigoberto', 655, 664, u'PERSON')
# (u'\n', 666, 667, u'GPE')
# (u'\n', 687, 688, u'GPE')
# (u'Cacho', 688, 693, u'GPE')
# (u'Carlos m', 698, 706, u'FAC')
# (u'Carmen', 719, 725, u'ORG')
# (u'\n', 727, 728, u'GPE')
# (u'Carmela', 728, 735, u'PERSON')
# (u'\n', 748, 749, u'GPE')
# (u'Carmelina', 749, 758, u'LOC')
# (u'Carmelita', 762, 771, u'GPE')
# (u'Carmen', 776, 782, u'GPE')
# (u'\n', 784, 785, u'GPE')
# (u'Carmencho for Carmen', 785, 805, u'ORG')
# (u'\n', 807, 808, u'GPE')
# (u'Carmenchu', 808, 817, u'GPE')
# (u'\n', 852, 853, u'GPE')
# (u'Carmina', 853, 860, u'GPE')
# (u'Carmen', 865, 871, u'GPE')
# (u'\n', 873, 874, u'GPE')
# (u'Carmucha', 895, 903, u'ORG')
# (u'Carmen', 908, 914, u'ORG')
# (u'\n', 916, 917, u'GPE')
# (u'Carolina', 926, 934, u'ORG')
# (u'Carola', 941, 947, u'PERSON')
# (u'Carolina', 960, 968, u'ORG')
# (u'\n', 970, 971, u'GPE')
# (u'Cata for Catalina', 971, 988, u'ORG')
# (u'Catalina f\nChabela for Isabel', 1000, 1029, u'ORG')
# (u'\n', 1031, 1032, u'GPE')
# (u'Mexico', 1054, 1060, u'GPE')
# (u'\n', 1061, 1062, u'GPE')
# (u'Chale for Carlos m\n', 1062, 1081, u'ORG')
# (u'Rosario', 1091, 1098, u'ORG')
# (u'\n', 1100, 1101, u'GPE')
# (u'Mexico', 1144, 1150, u'GPE')
# (u'\n', 1151, 1152, u'GPE')
# (u'Chayo for Rosario', 1152, 1169, u'ORG')
# (u'Mexico', 1173, 1179, u'GPE')
# (u'\n', 1180, 1181, u'GPE')
# (u'Jos\xe9 m', 1214, 1220, u'FAC')
# (u'Mar\xeda Jos\xe9 f', 1225, 1237, u'PRODUCT')
# (u'\n', 1237, 1238, u'GPE')
# (u'Checho', 1238, 1244, u'GPE')
# (u'Sergio m\n', 1249, 1258, u'ORG')
# (u'Sergio m\nChela', 1268, 1282, u'ORG')
# (u'Graciela', 1287, 1295, u'GPE')
# (u'Marcela', 1297, 1304, u'ORG')
# (u'Araceli', 1306, 1313, u'GPE')
# (u'\n', 1315, 1316, u'GPE')
# (u'Consuelo', 1326, 1334, u'PERSON')
# (u'Marcelo', 1341, 1348, u'ORG')
# (u'\n', 1350, 1351, u'GPE')
# (u'Jos\xe9 Mar\xeda', 1361, 1371, u'PERSON')
# (u'\n', 1373, 1374, u'GPE')
# (u'Chendo', 1374, 1380, u'GPE')
# (u'Rosendo m', 1385, 1394, u'ORG')
# (u'\n', 1394, 1395, u'GPE')
# (u'Chente', 1395, 1401, u'GPE')
# (u'\nCheo', 1415, 1420, u'ORG')
# (u'Jos\xe9', 1425, 1429, u'ORG')
# (u'\n', 1431, 1432, u'GPE')
# (u'Josefa', 1442, 1448, u'PERSON')
# (u'\n', 1450, 1451, u'GPE')
# (u'Chepina', 1451, 1458, u'GPE')
# (u'Josefina', 1463, 1471, u'GPE')
# (u'\n', 1473, 1474, u'GPE')
# (u'Ch\xeda', 1474, 1478, u'PRODUCT')
# (u'Luc\xeda f\nChicha', 1483, 1497, u'ORG')
# (u'Francisca', 1502, 1511, u'GPE')
# (u'Mar\xeda', 1515, 1520, u'GPE')
# (u'\n', 1528, 1529, u'GPE')
# (u'Francisco', 1540, 1549, u'GPE')
# (u'Narciso m\nChimo for Joaqu\xedn', 1553, 1580, u'ORG')
# (u'Roc\xedo', 1610, 1615, u'GPE')
# (u'Ascensi\xf3n', 1627, 1636, u'PRODUCT')
# (u'Asunci\xf3n', 1640, 1648, u'GPE')
# (u'\n', 1650, 1651, u'GPE')
# (u'Chucho', 1651, 1657, u'GPE')
# (u'Jes\xfas', 1662, 1667, u'GPE')
# (u'\n', 1669, 1670, u'GPE')
# (u'Jes\xfas m', 1679, 1686, u'MONEY')
# (u'Mar\xeda', 1694, 1699, u'GPE')
# (u'\n', 1707, 1708, u'GPE')
# (u'Jes\xfas', 1717, 1722, u'GPE')
# (u'\n', 1724, 1725, u'GPE')
# (u'Concepci\xf3n f\nConchi for Concepci\xf3n', 1776, 1810, u'ORG')
# (u'Concepci\xf3n', 1826, 1836, u'GPE')
# (u'Concho', 1839, 1845, u'FAC')
# (u'\n', 1860, 1861, u'GPE')
# (u'Coni', 1861, 1865, u'PERSON')
# (u'Consuelo', 1884, 1892, u'PERSON')
# (u'Constanza', 1899, 1908, u'PERSON')
# (u'Crist\xf3bal', 1938, 1947, u'ORG')
# (u'Cristina', 1957, 1965, u'GPE')
# (u'\n', 1967, 1968, u'GPE')
# (u'Mar\xeda', 1977, 1982, u'GPE')
# (u'Refugio', 1987, 1994, u'PERSON')
# (u'Mexico', 1998, 2004, u'NORP')
# (u'\n', 2005, 2006, u'GPE')
# (u'Curro', 2025, 2030, u'ORG')
# (u'Francisco', 2035, 2044, u'ORG')
# (u'\n', 2062, 2063, u'GPE')
# (u'Dago', 2063, 2067, u'PERSON')
# (u'Dagoberto', 2072, 2081, u'PERSON')
# (u'\n', 2083, 2084, u'GPE')
# (u'Daniel m', 2093, 2101, u'PERSON')
# (u'Daniela', 2105, 2112, u'GPE')
# (u'\n', 2114, 2115, u'GPE')
# (u'Dora', 2115, 2119, u'PERSON')
# (u'Teodora', 2124, 2131, u'PERSON')
# (u'Dorotea', 2135, 2142, u'PERSON')
# (u'\nEdu for Eduardo to m\nEncarna for Encarnaci\xf3n f\nEli for Elisabeth or Elisenda f\nFallo for Rafael m\n', 2146, 2245, u'WORK_OF_ART')
# (u'Federico', 2254, 2262, u'GPE')
# (u'\n', 2264, 2265, u'GPE')
# (u'Felipe', 2274, 2280, u'ORG')
# (u'F\xe9lix', 2282, 2287, u'ORG')
# (u'Feliciano', 2289, 2298, u'GPE')
# (u'Felisa', 2308, 2314, u'ORG')
# (u'\nFer for', 2316, 2324, u'ORG')
# (u'Fernando m\n', 2325, 2336, u'ORG')
# (u'Fina for', 2336, 2344, u'ORG')
# (u'Josefina', 2345, 2353, u'GPE')
# (u'Delfina', 2355, 2362, u'GPE')
# (u'Serafina', 2364, 2372, u'GPE')
# (u'\n', 2374, 2375, u'GPE')
# (u'Rodolfo m', 2392, 2401, u'MONEY')
# (u'\n', 2401, 2402, u'GPE')
# (u'Florencia', 2411, 2420, u'PERSON')
# (u'\n', 2422, 2423, u'GPE')
# (u'Florencia', 2433, 2442, u'PERSON')
# (u'\n', 2444, 2445, u'GPE')
# (u'Franc for Franco', 2465, 2481, u'ORG')
# (u'Francisco', 2485, 2494, u'ORG')
# (u'\n', 2496, 2497, u'GPE')
# (u'Frasco', 2497, 2503, u'ORG')
# (u'Frasquito', 2508, 2517, u'GPE')
# (u'Francisco', 2521, 2530, u'GPE')
# (u'Francisca', 2547, 2556, u'ORG')
# (u'\nFroi for Froil\xe1n m\n', 2558, 2578, u'ORG')
# (u'Rafael m', 2588, 2596, u'PERSON')
# (u'\n', 2596, 2597, u'GPE')
# (u'Gabi', 2597, 2601, u'GPE')
# (u'Gabriel m', 2606, 2615, u'MONEY')
# (u'Gabriela', 2617, 2625, u'PERSON')
# (u'\n', 2627, 2628, u'GPE')
# (u'Mar\xeda de los \xc1ngeles', 2667, 2687, u'PERSON')
# (u'\n', 2689, 2690, u'GPE')
# (u'\n', 2709, 2710, u'GPE')
# (u'G\xfcicho', 2710, 2716, u'PERSON')
# (u'Luis m\nGuille for Guillermo m\n', 2721, 2751, u'ORG')
# (u'Guillo', 2751, 2757, u'GPE')
# (u'Guillermo', 2762, 2771, u'GPE')
# (u'Inmaculada', 2783, 2793, u'GPE')
# (u'\n', 2795, 2796, u'GPE')
# (u'Ismael', 2822, 2828, u'GPE')
# (u'\n', 2830, 2831, u'GPE')
# (u'Isra', 2831, 2835, u'GPE')
# (u'Israel', 2840, 2846, u'GPE')
# (u'\n', 2848, 2849, u'GPE')
# (u'Iv\xe1n', 2857, 2861, u'ORG')
# (u'\n', 2863, 2864, u'GPE')
# (u'Jacinta', 2886, 2893, u'PERSON')
# (u'\n', 2895, 2896, u'GPE')
# (u'Jano', 2896, 2900, u'PERSON')
# (u'Alejandro', 2905, 2914, u'GPE')
# (u'\n', 2916, 2917, u'GPE')
# (u'Jacinta', 2938, 2945, u'PERSON')
# (u'Javier', 2957, 2963, u'PERSON')
# (u'Francisco Javier', 2967, 2983, u'PERSON')
# (u'\n', 2985, 2986, u'GPE')
# (u'Jennifer', 2996, 3004, u'PERSON')
# (u'\nJosean for', 3006, 3017, u'ORG')
# (u'Jos\xe9 Antonio', 3018, 3030, u'PERSON')
# (u'Jos\xe9 Andr\xe9s', 3034, 3045, u'PERSON')
# (u'\n', 3047, 3048, u'GPE')
# (u'Josema', 3048, 3054, u'PERSON')
# (u'Jos\xe9 Mar\xeda', 3059, 3069, u'PERSON')
# (u'Jos\xe9 Manuel', 3073, 3084, u'PERSON')
# (u'\n', 3086, 3087, u'GPE')
# (u'Jos\xe9 Miguel', 3098, 3109, u'PERSON')
# (u'\n', 3111, 3112, u'GPE')
# (u'Jos\xe9 Vicente', 3121, 3133, u'PERSON')
# (u'\n', 3135, 3136, u'GPE')
# (u'Juanan', 3136, 3142, u'GPE')
# (u'Juan Antonio', 3147, 3159, u'PERSON')
# (u'Juan Andr\xe9s', 3163, 3174, u'PRODUCT')
# (u'\n', 3176, 3177, u'GPE')
# (u'Juan Jos\xe9 m', 3189, 3200, u'PRODUCT')
# (u'\nJuanfer', 3200, 3208, u'PERSON')
# (u'Juanfran', 3229, 3237, u'PRODUCT')
# (u'Juan Francisco', 3242, 3256, u'PRODUCT')
# (u'\n', 3258, 3259, u'GPE')
# (u'Juan Jos\xe9', 3270, 3279, u'PERSON')
# (u'\n', 3281, 3282, u'GPE')
# (u'Juanlu', 3282, 3288, u'ORG')
# (u'Juan Luis m\nJuanma', 3293, 3311, u'PRODUCT')
# (u'Juan Manuel', 3316, 3327, u'PERSON')
# (u'Juan Mar\xeda', 3331, 3341, u'PERSON')
# (u'\n', 3343, 3344, u'GPE')
# (u'Juanmi', 3344, 3350, u'PERSON')
# (u'Juan Miguel', 3355, 3366, u'PERSON')
# (u'\n', 3368, 3369, u'GPE')
# (u'Juan Pablo', 3380, 3390, u'PRODUCT')
# (u'Juansa', 3393, 3399, u'PRODUCT')
# (u'Juan Salvador', 3404, 3417, u'PRODUCT')
# (u'\n', 3419, 3420, u'GPE')
# (u'Juan Vicente m', 3431, 3445, u'MONEY')
# (u'\n', 3445, 3446, u'GPE')
# (u'Enrique', 3455, 3462, u'GPE')
# (u'\n', 3464, 3465, u'GPE')
# (u'Kiko', 3465, 3469, u'PERSON')
# (u'Federico', 3474, 3482, u'GPE')
# (u'Francisco', 3484, 3493, u'GPE')
# (u'\n', 3495, 3496, u'GPE')
# (u'Lalo for Eduardo', 3496, 3512, u'ORG')
# (u'Abelardo', 3514, 3522, u'GPE')
# (u'Ladislao m\nLena', 3524, 3539, u'ORG')
# (u'Elena', 3544, 3549, u'ORG')
# (u'Magdalena', 3553, 3562, u'ORG')
# (u'\n', 3564, 3565, u'GPE')
# (u'Elena', 3595, 3600, u'ORG')
# (u'Magdalena', 3604, 3613, u'ORG')
# (u'Leo for Leopoldo, Leandro, Leonardo', 3616, 3651, u'WORK_OF_ART')
# (u'Leoncio', 3653, 3660, u'PERSON')
# (u'Leocadia', 3669, 3677, u'ORG')
# (u'\n', 3679, 3680, u'GPE')
# (u'Leticia', 3689, 3696, u'PERSON')
# (u'Leticia', 3708, 3715, u'PERSON')
# (u'Alicia', 3728, 3734, u'PERSON')
# (u'\n', 3755, 3756, u'GPE')
# (u'Loles for Dolores f', 3756, 3775, u'ORG')
# (u'\nLoli for Dolores', 3775, 3792, u'ORG')
# (u'\n', 3794, 3795, u'GPE')
# (u'Loren for Lorenzo m\nLucero for Mar\xeda de la Luz', 3834, 3880, u'ORG')
# (u'\nLucha', 3908, 3914, u'ORG')
# (u'\n', 3926, 3927, u'GPE')
# (u'Luis', 3937, 3941, u'PERSON')
# (u'Luis Miguel m', 3964, 3977, u'PERSON')
# (u'\n', 3977, 3978, u'GPE')
# (u'Mabel for Mar\xeda Isabel', 4041, 4063, u'WORK_OF_ART')
# (u'\n', 4065, 4066, u'GPE')
# (u'Macarena', 4075, 4083, u'PERSON')
# (u'Macu', 4086, 4090, u'PERSON')
# (u'Inmaculada', 4095, 4105, u'ORG')
# (u'\nMafe', 4107, 4112, u'GPE')
# (u'\n', 4133, 4134, u'GPE')
# (u'Magda for Magdalena f\nMaite', 4134, 4161, u'ORG')
# (u'Mayte', 4165, 4170, u'GPE')
# (u'Mar\xeda Teresa', 4175, 4187, u'GPE')
# (u'\n', 4189, 4190, u'GPE')
# (u'Malena', 4190, 4196, u'GPE')
# (u'Mar\xeda', 4201, 4206, u'GPE')
# (u'Mar\xeda Magdalena', 4216, 4231, u'ORG')
# (u'\n', 4233, 4234, u'GPE')
# (u'Mamen for Mar\xeda del Carmen', 4234, 4260, u'ORG')
# (u'\n', 4262, 4263, u'GPE')
# (u'Armando m\n', 4273, 4283, u'MONEY')
# (u'Manola', 4283, 4289, u'GPE')
# (u'Manuela', 4294, 4301, u'GPE')
# (u'\n', 4303, 4304, u'GPE')
# (u'Manuela', 4315, 4322, u'GPE')
# (u'\n', 4324, 4325, u'GPE')
# (u'Manuel', 4354, 4360, u'PERSON')
# (u'Manuela', 4366, 4373, u'PERSON')
# (u'\n', 4375, 4376, u'GPE')
# (u'Mar\xeda', 4385, 4390, u'GPE')
# (u'\n', 4392, 4393, u'GPE')
# (u'Mar\xeda', 4435, 4440, u'GPE')
# (u'Carmen', 4445, 4451, u'GPE')
# (u'\n', 4453, 4454, u'GPE')
# (u'Marichu', 4454, 4461, u'GPE')
# (u'Mar\xeda', 4466, 4471, u'GPE')
# (u'\n', 4479, 4480, u'GPE')
# (u'Mari\xe9n for Mar\xeda Elena', 4480, 4502, u'ORG')
# (u'\n', 4504, 4505, u'GPE')
# (u'Marilena for Mar\xeda Elena', 4505, 4529, u'ORG')
# (u'Mar\xeda Magdalena', 4533, 4548, u'ORG')
# (u'Marimar', 4551, 4558, u'GPE')
# (u'Mar\xeda', 4563, 4568, u'GPE')
# (u'\n', 4578, 4579, u'GPE')
# (u'Mar\xeda de la Luz', 4603, 4618, u'GPE')
# (u'\n', 4620, 4621, u'GPE')
# (u'Maripepa', 4621, 4629, u'NORP')
# (u'Mar\xeda', 4634, 4639, u'GPE')
# (u'Mar\xeda Jos\xe9', 4650, 4660, u'PERSON')
# (u'\n', 4662, 4663, u'GPE')
# (u'Marisa', 4663, 4669, u'GPE')
# (u'Mar\xeda', 4674, 4679, u'GPE')
# (u'\n', 4713, 4714, u'GPE')
# (u'Martincho', 4714, 4723, u'ORG')
# (u'Mart\xedn', 4728, 4734, u'GPE')
# (u'\n', 4754, 4755, u'GPE')
# (u'\n', 4775, 4776, u'GPE')
# (u'Maximiliano', 4792, 4803, u'ORG')
# (u'Maximino', 4805, 4813, u'GPE')
# (u'\n', 4815, 4816, u'GPE')
# (u'M\xe1ximo', 4825, 4831, u'PERSON')
# (u'Maximiliano', 4833, 4844, u'PERSON')
# (u'Maximino', 4846, 4854, u'GPE')
# (u'\n', 4856, 4857, u'GPE')
# (u'Meche', 4857, 4862, u'ORG')
# (u'Mercedes', 4867, 4875, u'ORG')
# (u'\n', 4877, 4878, u'GPE')
# (u'Meme', 4878, 4882, u'PERSON')
# (u'Manuel', 4887, 4893, u'PERSON')
# (u'Texas', 4897, 4902, u'GPE')
# (u'\n', 4903, 4904, u'GPE')
# (u'Memel', 4904, 4909, u'PERSON')
# (u'Jos\xe9 Manuel', 4914, 4925, u'PERSON')
# (u'\n', 4927, 4928, u'GPE')
# (u'Mercedes', 4959, 4967, u'ORG')
# (u'\nMerche', 4969, 4976, u'ORG')
# (u'Merchi', 4980, 4986, u'ORG')
# (u'Mercedes', 4991, 4999, u'ORG')
# (u'Minerva', 5011, 5018, u'PERSON')
# (u'\n', 5020, 5021, u'GPE')
# (u'Mingo', 5021, 5026, u'GPE')
# (u'Domingo', 5031, 5038, u'GPE')
# (u'\n', 5040, 5041, u'GPE')
# (u'Ram\xf3n m\nNacho for Ignacio m\n', 5052, 5080, u'ORG')
# (u'Fernando m\nNata for Renata', 5112, 5138, u'ORG')
# (u'Natalia', 5150, 5157, u'GPE')
# (u'\n', 5159, 5160, u'GPE')
# (u'\n', 5180, 5181, u'GPE')
# (u'Neto', 5181, 5185, u'GPE')
# (u'N\xe9stor', 5190, 5196, u'DATE')
# (u'Ernesto', 5200, 5207, u'GPE')
# (u'\n', 5209, 5210, u'GPE')
# (u'Nico', 5210, 5214, u'GPE')
# (u'Nicol\xe1s', 5219, 5226, u'FAC')
# (u'Nicodemo m\n', 5230, 5241, u'FAC')
# (u'Nines for', 5241, 5250, u'PRODUCT')
# (u'\nNuchi', 5260, 5266, u'ORG')
# (u'Encarnaci\xf3n', 5271, 5282, u'NORP')
# (u'\n', 5284, 5285, u'GPE')
# (u'Oli for Olivio or Oliverio', 5285, 5311, u'ORG')
# (u'Francisca', 5323, 5332, u'ORG')
# (u'\n', 5334, 5335, u'GPE')
# (u'Francisco', 5345, 5354, u'ORG')
# (u'\n', 5356, 5357, u'GPE')
# (u'\n', 5377, 5378, u'GPE')
# (u'Pancho', 5378, 5384, u'GPE')
# (u'Francisco', 5389, 5398, u'ORG')
# (u'\n', 5400, 5401, u'GPE')
# (u'Francisca', 5411, 5420, u'ORG')
# (u'Francisco', 5424, 5433, u'ORG')
# (u'\n', 5461, 5462, u'GPE')
# (u'Francisco', 5474, 5483, u'ORG')
# (u'\n', 5485, 5486, u'GPE')
# (u'Pepa for Josefa f\n', 5486, 5504, u'ORG')
# (u'Jos\xe9 m\n', 5513, 5520, u'ORG')
# (u'Jos\xe9 m\nPepita', 5530, 5543, u'MONEY')
# (u'\n', 5556, 5557, u'GPE')
# (u'Pepito', 5557, 5563, u'PERSON')
# (u'Jos\xe9', 5568, 5572, u'PERSON')
# (u'\n', 5574, 5575, u'GPE')
# (u'\n', 5629, 5630, u'GPE')
# (u'Josefa', 5639, 5645, u'PERSON')
# (u'\n', 5647, 5648, u'GPE')
# (u'Leopoldo m\nPoncho for Alfonso m\n', 5679, 5711, u'ORG')
# (u'Francisca', 5721, 5730, u'LOC')
# (u'\n', 5732, 5733, u'GPE')
# (u'Francisco', 5743, 5752, u'ORG')
# (u'\n', 5754, 5755, u'GPE')
# (u'Joaqu\xedn m\nQuique', 5765, 5781, u'ORG')
# (u'Enrique m\nRafa', 5786, 5800, u'ORG')
# (u'Rafael', 5805, 5811, u'GPE')
# (u'Rafi', 5814, 5818, u'GPE')
# (u'Rafael', 5823, 5829, u'PERSON')
# (u'Rafaela', 5833, 5840, u'ORG')
# (u'm-f', 5841, 5844, u'PRODUCT')
# (u'Maria', 5872, 5877, u'GPE')
# (u'\n', 5879, 5880, u'GPE')
# (u'Richi', 5880, 5885, u'GPE')
# (u'Ricardo', 5890, 5897, u'GPE')
# (u'\n', 5899, 5900, u'GPE')
# (u'Roberto', 5910, 5917, u'GPE')
# (u'\n', 5919, 5920, u'GPE')
# (u'Rodolfo m\nRodri', 5929, 5944, u'MONEY')
# (u'Rodrigo', 5949, 5956, u'GPE')
# (u'Rosa', 5968, 5972, u'PERSON')
# (u'\n', 5974, 5975, u'GPE')
# (u'Ra\xfal m', 5984, 5990, u'PRODUCT')
# (u'Rodrigo', 5999, 6006, u'GPE')
# (u'\n', 6008, 6009, u'GPE')
# (u'Sabri', 6009, 6014, u'PERSON')
# (u'Sabrina f\nSalva', 6019, 6034, u'ORG')
# (u'Salvador', 6039, 6047, u'GPE')
# (u'\n', 6049, 6050, u'GPE')
# (u'Samuel m', 6059, 6067, u'PERSON')
# (u'\n', 6067, 6068, u'GPE')
# (u'\n', 6113, 6114, u'GPE')
# (u'\n', 6134, 6135, u'GPE')
# (u'Sebas', 6135, 6140, u'GPE')
# (u'Segismundo', 6167, 6177, u'GPE')
# (u'\n', 6179, 6180, u'GPE')
# (u'Severo', 6189, 6195, u'GPE')
# (u'Severino', 6197, 6205, u'ORG')
# (u'Severiano', 6207, 6216, u'GPE')
# (u'\n', 6218, 6219, u'GPE')
# (u'Sonsi for Sonsoles', 6219, 6237, u'ORG')
# (u'Susana', 6249, 6255, u'GPE')
# (u'Jes\xfas', 6267, 6272, u'GPE')
# (u'\n', 6274, 6275, u'GPE')
# (u'Hortencia', 6286, 6295, u'ORG')
# (u'\n', 6297, 6298, u'GPE')
# (u'Te\xf3filo m\n', 6317, 6327, u'MONEY')
# (u'Teresa', 6336, 6342, u'ORG')
# (u'\n', 6344, 6345, u'GPE')
# (u'Cristina', 6381, 6389, u'GPE')
# (u'Ernestina', 6391, 6400, u'GPE')
# (u'Florentina', 6402, 6412, u'GPE')
# (u'Valentina', 6414, 6423, u'GPE')
# (u'\n', 6430, 6431, u'GPE')
# (u'Agust\xedn', 6460, 6467, u'DATE')
# (u'Cristino', 6469, 6477, u'LANGUAGE')
# (u'\n', 6507, 6508, u'GPE')
# (u'Tito', 6508, 6512, u'PERSON')
# (u'Alberto', 6517, 6524, u'PERSON')
# (u'Norberto', 6536, 6544, u'PERSON')
# (u'Roberto', 6546, 6553, u'PERSON')
# (u'Rigoberto', 6557, 6566, u'PERSON')
# (u'\n', 6568, 6569, u'GPE')
# (u'Tom\xe1s m', 6578, 6585, u'MONEY')
# (u'\n', 6585, 6586, u'GPE')
# (u'Toni', 6611, 6615, u'PERSON')
# (u'To\xf1i for Antonia f\n', 6648, 6667, u'ORG')
# (u'\nTo\xf1o', 6685, 6690, u'ORG')
# (u'Toya for Victoria f\nTrini for Trinidad', 6705, 6743, u'ORG')
# (u'Texas', 6747, 6752, u'GPE')
# (u'\n', 6753, 6754, u'GPE')
# (u'\n', 6773, 6774, u'GPE')
# (u'Ver\xf3nica', 6783, 6791, u'GPE')
# (u'\n', 6793, 6794, u'GPE')
# (u'Vicen', 6794, 6799, u'GPE')
# (u'Vicente', 6804, 6811, u'PERSON')
# (u'Vicenta', 6815, 6822, u'GPE')
# (u'\n', 6826, 6827, u'GPE')
# (u'\n', 6856, 6857, u'GPE')
# (u'Bico', 6865, 6869, u'GPE')
# (u'Victoria', 6874, 6882, u'GPE')
# (u'\n', 6884, 6885, u'GPE')
# (u'Victoria f\nWences for Wenceslao m\n', 6894, 6928, u'FAC')
# (u'Yola', 6948, 6952, u'GPE')
# (u'Yolanda f\n', 6957, 6967, u'ORG')
# (u'Yoli for Yolanda f\nZaca', 6967, 6990, u'ORG')
# (u'Zacar\xedas', 6995, 7003, u'GPE')
